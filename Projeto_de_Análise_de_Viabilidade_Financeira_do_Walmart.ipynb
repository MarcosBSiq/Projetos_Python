# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosBSiq/Projetos_Python/blob/main/Projeto_de_An%C3%A1lise_de_Viabilidade_Financeira_do_Walmart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto de análise de viabilidade financeira do Walmart
# ________________________________________________________________________________
#
# CONTEXTUALIZAÇÃO
#
# Você foi contratado pelo Walmart para fazer um levantamento do
# faturamento das lojas nos USA e apontar qual loja seria melhor para
# expandir seu tamanho.
# É preciso analisar as vendas semanais de cada loja, calcular algumas
# informações importantes que serão perguntadas e ao final de tudo, indicar
# em qual loja deva ser investida.

# %% [markdown]
# ## DESCRIÇÃO DAS VARIÁVEIS PRESENTES NA BASE DE DADOS
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Relatório Descritivo

# %% [markdown]
# #Autor: Marcos Bolsoni Siqueira
#
# ##A Questão de Negócio
#
# Neste projeto o objetivo é analisar os dados disponibilizados pelo cliente Walmart, famosa multinacional estadunidense de lojas de departamento, que está buscando saber em qual das 45 lojas presentes no data frame seria mais interessante realizar a expansão de seu tamanho. Dito isto, após a análise exploratória dos dados será realizada a indicação de qual destas lojas deveria receber um investimento de expansão.
#
#
# ##1.	Business Understanding
# A base de dados disponibilizada para as análises contém as seguintes informações:
#
# •	‘Store’ (número inteiro que identifica cada loja);
#
# •	‘Date’ (data que representa a semana das vendas naquela loja);
#
# •	‘Weekly_Sales’ (valor das vendas naquela semana);
#
# •	‘Holiday_Flag’ (indicador que mostra se aquela foi uma semana com feriado, marcado como 1 ou se na semana não houve feriado, identificado como 0);
#
# •	‘Temperature’ (temperatura do dia em Fº);
#
# •	‘Fuel_Price’ (preço do combustível na região da loja);
#
# •	‘CPI’ (índice de preços ao consumidor);
#
# •	‘Unemployment’ (taxa de desemprego);
#
# ##2.	Data Understanding
#
# 2.1	Coleta de dados e limpeza dos dados
# Em uma análise inicial dos dados disponíveis já é possível identificar algumas questões e verificar se existem anomalias nos dados disponíveis. Primeiramente, utilizando a biblioteca pandas é possível fazer a importação da base de dados para dentro do Google Colab e verificar quais são os tipos dos dados de cada uma das variáveis. Foram importadas também as bibliotecas numpy para tratamento e exploração dos dados, bem como as bibliotecas seaborn e matplotlib e plotly para visualização dos dados.
#
# Buscando as informações dos dados presentes no data frame é possível notar que a variável ‘date’ está como o tipo objeto o que demandará que estes dados sejam convertidos no tipo datetime para facilitar a análise temporal dos dados. Também é possível notar neste momento que não existem valores nulos no data frame e também não existem entradas de linhas duplicadas.
#
# Sentiu-se a necessidade de adicionar 4 novas colunas ao dataset original, cada uma destas colunas é referente à um dos 4 feriados norte-americanos específicos dentre as datas disponibilizadas. Sendo estes 4 feriados:
#
# •	Super Bowl (ocorrido na semana dos dias 12/02/2010, 11/02/2011 e 10/02/2012);
#
# •	Labor Day (ocorrido na semana dos dias 10/09/2010, 09/09/2011 e 07/09/2012);
#
# •	Thanksgiving (ocorrido na semana dos dias 26/11/2010, 25/11/2011 e 23/11/2012);
#
# •	Christmas (ocorrido na semana dos dias 31/12/2010, 30/12/2011 e 28/12/2012).
#
# Desta maneira caso o campo ‘Date’ se encaixasse em alguma das datas específicas citadas acima ele fica identificado como ‘True’ na coluna correspondente ao feriado correto enquanto todas as demais ficam identificadas como ‘False’. Desta maneira é possível realizar análises específicas para cada um dos feriados se assim desejado.
#
# Por fim, foi criado um outro data frame a partir da junção das informações das médias das vendas semanais de todas as lojas com um data frame contendo os valores de vendas semanais da loja que apresentou maior faturamento acumulado em todo o período, abordarei mais a fundo posteriormente.
#
# ##2.2	Exploração dos dados
#
# A principal variável que embasou a análise deste projeto foi o faturamento das lojas. Para isto esta variável foi observada ao longo das semanas e também de maneira acumulada e agrupada em semanas com e sem feriados visando identificar o impacto de tais datas comemorativas no faturamento observado.
#
# Através de um gráfico do tipo boxplot tendo as lojas como eixo x e o faturamento semanal no eixo y foi possível observar que dentre praticamente todas as lojas existiam outliers devido a algumas semanas específicas em que o desempenho de faturamento de cada loja se desgarrou das tendências de faturamento médio daquele estabelecimento. Já aqui foi possível observar que as lojas 20 e loja 4 possuíam as maiores medianas dentro do conjunto de dados, indicando ser duas das melhores lojas no quesito de faturamento.
#
#
# Através de outras duas tabelas e dois gráficos de barra contendo o faturamento médio semanal e faturamento total semanal das lojas observa-se que de fato as lojas 20 e 4 são as duas que mais se destacaram dentre as demais. Em ambas as análises a loja 20 demonstrou resultados ligeiramente superiores. Deste modo partiu-se do entendimento que a loja 20 teve um resultado suficientemente relevante para ser considerada a melhor loja para receber o investimento do Walmart.
#
# A seguir foram analisados os impactos que os feriados têm sobre as vendas das lojas, bem como, foi verificado se alguma outra variável do data frame tem impacto sobre o faturamento das lojas.
#
# Foi criado um gráfico do tipo boxplot tendo as lojas no eixo x e o faturamento semanal no eixo y, além disto, as informações das vendas foram separadas de acordo com as vendas nos feriados (barras laranjadas) e vendas em semanas sem feriado (barras azuis) e de fato foi possível notar que na grande maioria dos casos as semanas onde houveram feriados tiveram desempenho de vendas superiores àquelas semanas em que não houveram feriados.
#
# Em mais uma análise sobre os feriados foi possível notar através de um gráfico de barras que dentre os feriados as semanas de 26/11/2010 e 25/11/2011 (ambas as datas referentes a semana do feriado de Thanksgiving) foram aquelas que mais impactaram positivamente as vendas das lojas ao passo que a semana do natal do ano de 2010 foi aquela com pior faturamento acumulado dentre todos os feriados.
#
# Foi criado um mapa de calor para verificar a correlação entre as demais variáveis e o faturamento das lojas. O que se observou é que nenhuma das variáveis possui uma correlação alta com o faturamento, nenhuma delas chegou a ter 0,5 ou -0,5 pontos de correlação. Porém, vale notar que as duas variáveis com maior correlação, ambas correlações negativas com o faturamento, foram a taxa de desemprego e o índice de preços ao consumidor, o que faz sentido uma vez que quanto menor for a taxa de desemprego e índice de inflação maior é a tendência de que o faturamento das lojas aumente.
#
# Por fim, analisado o desempenho geral das 45 lojas a loja de número 20 foi aquela que mais se destacou, para ajudar a comprovar este argumento foi gerado um gráfico de barras interativo, possibilitando zoom nos períodos desejados, contendo as vendas semanais da loja 20 comparadas com a média de vendas de todas as lojas. Foi observado que em todas as semanas ao longo dos 3 anos o faturamento da loja escolhida foi superior à média de faturamento de todas as lojas.
#
#
# ##3. Análise final e sugestão de compra
#
# Após realizar a compreensão dos dados, limpeza e tratamento dos mesmos seguidos de uma análise estatística descritiva e inferencial chegou-se à conclusão de que a loja 20 é aquela que merece receber um investimento de expansão por apresentar os melhores desempenhos em vendas ao longo de todo o período analisado, seja comparando médias de faturamento, faturamento acumulado ou até mesmo desempenho em feriados. Além disto, também se recomenda que caso a empresa deseje realizar ações promocionais para atrair maiores vendas em semanas de feriados é interessante escolher a semana do feriado de Ação de Graças (Thanksgiving) pois mostrou ser o feriado que mais atraiu vendas nos anos analisados.

# %% [markdown]
# #Instalação e importação das bibliotecas

# %%
# !pip install uszipcode 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 76 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 121 kB 72.6 MB/s
# ...

# %% [markdown]
# #Importação da base de dados

# %%
# IMPORTAÇÃO DA BASE DE DADOS

df = pd.read_csv('/content/Walmart.csv')


# PRINTANDO AS 5 PRIMEIRAS LINHAS DA BASE DE DADOS

df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %% [markdown]
# #Compreensão e tratamento dos dados

# %%
# Identificando informações gerais (tipagem dos dados, colunas existentes e número de registros)

df.info()


print()

# Identificnado a existência de dados em branco

print(df.isnull().sum())

# Identificando a existência de entradas duplicadas

print(df.duplicated().sum())

# Transformando o campo Date no tipo datetime

df['Date'] = pd.to_datetime(df['Date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB
#
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
# ...

# %%
# Adicionando colunas para identificar qual é o feriado em cada data

# Semanas do Super Bowl

df.loc[(df['Date'] == '12-02-2010')|(df['Date'] == '11-02-2011')|(df['Date'] == '10-02-2012'),'Super_Bowl'] = True
df.loc[(df['Date'] != '12-02-2010')&(df['Date'] != '11-02-2011')&(df['Date'] != '10-02-2012'),'Super_Bowl'] = False

# Semanas do Labor Day

df.loc[(df['Date'] == '10-09-2010')|(df['Date'] == '09-09-2011')|(df['Date'] == '07-09-2012'),'Labor_Day'] = True
df.loc[(df['Date'] != '10-09-2010')&(df['Date'] != '09-09-2011')&(df['Date'] != '07-09-2012'),'Labor_Day'] = False

# Semanas do Thanksgiving
df.loc[(df['Date'] == '26-11-2010')|(df['Date'] == '25-11-2011'),'Thanksgiving'] = True
df.loc[(df['Date'] != '26-11-2010')&(df['Date'] != '25-11-2011'),'Thanksgiving'] = False

# Semanas do Christmas

df.loc[(df['Date'] == '31-12-2010')|(df['Date'] == '30-12-2011'),'Christmas'] = True
df.loc[(df['Date'] != '31-12-2010')&(df['Date'] != '30-12-2011'),'Christmas'] = False

display(df)
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
# Verificando se existe algum feriado diferente dos citados acima

outro_feriado = df[(df['Holiday_Flag'] == 1) & (df['Super_Bowl'] == False) & (df['Labor_Day'] == False)&(df['Thanksgiving'] == False)&(df['Christmas'] == False)]

display(outro_feriado)
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment, Super_Bowl, Labor_Day, Thanksgiving, Christmas]
# Index: []

# %% [markdown]
# #Análise dos dados

# %%
# Gráfico das vendas semanais por loja

fig, ax = plt.subplots(figsize=(40, 10))

plt. xlabel('Store', fontsize=15), plt. ylabel('Weekly_Sales', fontsize=15)

sns.boxplot (data = df, x = df['Store'] , y = df['Weekly_Sales']).set_title("Vendas Semanais por Loja");

# %%
# Preço médio das vendas semanais por loja e ordenadas de forma crescente pelo faturamento semanal

media_vendas = df.groupby(['Store']).mean().reset_index().sort_values('Weekly_Sales')

display(media_vendas)
# Out:
#     Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 32     33  2.598617e+05       0.06993    76.728182    3.575923  128.679669
# 43     44  3.027489e+05       0.06993    53.697133    3.286147  128.679669
# 4       5  3.180118e+05       0.06993    69.410140    3.219699  216.565581
# 35     36  3.735120e+05       0.06993    71.160350    3.204203  214.729069
# 37     38  3.857317e+05       0.06993    70.262797    3.606420  128.679669
# 2       3  4.027044e+05       0.06993    71.434196    3.219699  219.391531
# 29     30  4.385796e+05       0.06993    68.847622    3.219699  215.646311
# 36     37  5.189003e+05       0.06993    71.160350    3.219699  214.729069
# 15     16  5.192477e+05       0.06993    45.030070    3.241559  193.664243
# 28     29  5.394514e+05       0.06993    54.897133    3.441741  135.092607
# 8       9  5.439806e+05       0.06993    67.775175    3.219699  219.626689
# ...

# %%
# Gráfico da média das vendas semanais por loja

fig, ax = plt.subplots(figsize=(40, 10))

plt. xlabel('Store', fontsize=15), plt. ylabel('Weekly_Sales', fontsize=15)

sns.barplot (data = media_vendas, x = media_vendas['Store'] , y = media_vendas['Weekly_Sales']).set_title('Média de Vendas Semanais por Loja');

# %%
# Vendas semanais acumuladas por loja e ordeandas de forma crescente pelo faturamento semanal

soma_vendas = df.groupby(['Store']).sum().reset_index().sort_values('Weekly_Sales')

display(soma_vendas)
# Out:
#     Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price           CPI  \
# 32     33  3.716022e+07            10     10972.13     511.357  18401.192733
# 43     44  4.329309e+07            10      7678.69     469.919  18401.192733
# 4       5  4.547569e+07            10      9925.65     460.417  30968.878137
# 35     36  5.341221e+07            10     10175.93     458.201  30706.256907
# 37     38  5.515963e+07            10     10047.58     515.718  18401.192733
# 2       3  5.758674e+07            10     10215.09     460.417  31372.988971
# 29     30  6.271689e+07            10      9845.21     460.417  30837.422420
# 36     37  7.420274e+07            10     10175.93     460.417  30706.256907
# 15     16  7.425243e+07            10      6439.30     463.543  27693.986741
# 28     29  7.714155e+07            10      7850.29     492.169  19318.242848
# 8       9  7.778922e+07            10      9691.85     460.417  31406.616557
# ...

# %%
# Gráfico das vendas acumuladas por loja

fig, ax = plt.subplots(figsize=(40, 10))

plt. xlabel('Store', fontsize=15), plt. ylabel('Weekly_Sales', fontsize=15)

sns.barplot (data = soma_vendas, x = soma_vendas['Store'] , y = soma_vendas['Weekly_Sales']).set_title('Vendas acumuladas por Loja');

# %% [markdown]
# #Analisando vendas de acordo com feriados

# %%
# Gráfico das vendas em semanas de feriado e em semanas sem feriados

fig, ax = plt.subplots(figsize=(40, 10))

plt. xlabel('Store', fontsize=15), plt. ylabel('Weekly_Sales', fontsize=15)

sns.boxplot (data = df, x = 'Store' , y = 'Weekly_Sales', hue ='Holiday_Flag' ).set_title('Soma de Vendas  por Loja');

# %%
# Filtrando as vendas apenas pelas semanas que correspondem a feriados

soma_feriados = df[(df['Holiday_Flag'] == 1)]

soma_feriados['Date'] = pd.to_datetime(soma_feriados.Date)

soma_feriados['Date'] = df['Date'].dt.strftime('%Y/%m/%d')

display(soma_feriados)

# Plotando o Gráfico

fig, ax = plt.subplots(figsize=(40, 10))

plt. xlabel('Date', fontsize=15), plt. ylabel('Weekly_Sales', fontsize=15)

sns.barplot (data = soma_feriados, x = 'Date' , y = 'Weekly_Sales').set_title('Soma de Vendas  por feriados');
# Out:
# <ipython-input-12-88b3eda69cc5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   soma_feriados['Date'] = pd.to_datetime(soma_feriados.Date)
# <ipython-input-12-88b3eda69cc5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   soma_feriados['Date'] = df['Date'].dt.strftime('%Y/%m/%d')
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1         1  2010/12/02    1641957.44             1        38.51       2.548
# ...

# %% [markdown]
# #Analisando a correlação de outras variáveis com o faturamento

# %%
# Identificando os níveis de correlação entre vendas e demais variáveis:

sns.set(rc={'figure.figsize':(20,15)})

ax = sns.heatmap(df.corr(), annot=True, linewidths=0.5, fmt=".2f")

# %% [markdown]
# #Comparando o desempenho de vendas da loja 20 com as demais lojas

# %%
# Agrupando os dados pelas datas de acordo com a média

media_vendas_semana = df.groupby(['Date']).mean().reset_index().sort_values('Weekly_Sales')

display(media_vendas_semana)
# Out:
#           Date  Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 52  2011-01-28   23.0  8.799967e+05           0.0    34.064444    3.134689
# 103 2012-01-27   23.0  8.852217e+05           0.0    42.726000    3.411556
# 47  2010-12-31   23.0  8.985004e+05           1.0    36.782667    3.048222
# 51  2011-01-21   23.0  9.034366e+05           0.0    37.522222    3.126889
# 50  2011-01-14   23.0  9.038595e+05           0.0    30.689556    3.105000
# ..         ...    ...           ...           ...          ...         ...
# 45  2010-12-17   23.0  1.373796e+06           0.0    40.351778    3.005444
# 41  2010-11-26   23.0  1.462689e+06           1.0    47.889556    2.917956
# 95  2011-11-25   23.0  1.479858e+06           1.0    49.627556    3.434311
# 98  2011-12-23   23.0  1.711072e+06           0.0    39.611778    3.291978
# 46  2010-12-24   23.0  1.798476e+06           0.0    41.177333    3.021333
#
#             CPI  Unemployment
# 52   169.076008      8.291200
# ...

# %%
# Filtrando as vendas semanais apenas da loja 20

vendas_semanais_loja20 = df[['Date','Store','Weekly_Sales']]

vendas_semanais_loja20 = vendas_semanais_loja20[vendas_semanais_loja20['Store']==20]

vendas_semanais_loja20
# Out:
#            Date  Store  Weekly_Sales
# 2717 2010-05-02     20    2401395.47
# 2718 2010-12-02     20    2109107.90
# 2719 2010-02-19     20    2161549.76
# 2720 2010-02-26     20    1898193.95
# 2721 2010-05-03     20    2119213.72
# ...         ...    ...           ...
# 2855 2012-09-28     20    2008350.58
# 2856 2012-05-10     20    2246411.89
# 2857 2012-12-10     20    2162951.36
# 2858 2012-10-19     20    1999363.49
# 2859 2012-10-26     20    2031650.55
#
# [143 rows x 3 columns]

# %%
# Fazendo um join entre os dados de venda da loja 20 e a média de vendas de todas as lojas

df2 = pd.merge(media_vendas_semana, vendas_semanais_loja20, on=["Date","Date"], how="inner").reset_index()

df2['comparativo_media_vendas'] = 'Weekly_Sales_y'>'Weekly_Sales_x'

df2['year']= df2['Date'].dt.year

df2.sort_values('Date')
# Out:
#      index       Date  Store_x  Weekly_Sales_x  Holiday_Flag  Temperature  \
# 9        9 2010-01-10     23.0    9.386639e+05           0.0    69.868000
# 132    132 2010-02-04     23.0    1.120530e+06           0.0    53.120889
# 124    124 2010-02-07     23.0    1.087055e+06           0.0    77.133333
# 113    113 2010-02-19     23.0    1.072822e+06           0.0    37.719778
# 24      24 2010-02-26     23.0    9.770794e+05           0.0    39.243556
# ..     ...        ...      ...             ...           ...          ...
# 95      95 2012-10-08     23.0    1.053410e+06           0.0    81.580222
# 44      44 2012-10-19     23.0    1.002720e+06           0.0    60.705333
# 54      54 2012-10-26     23.0    1.012091e+06           0.0    61.051111
# 85      85 2012-11-05     23.0    1.042797e+06           0.0    64.838000
# 69      69 2012-12-10     23.0    1.025078e+06           0.0    58.342667
#
#      Fuel_Price         CPI  Unemployment  Store_y  Weekly_Sales_y  \
# ...

# %%
# Gráfico de comparação das vendas da loja 20 com a média de vendas de todas as lojas ao longo dos anos

fig = go.Figure()

fig.add_trace(go.Bar(x = df2['Date'], 
                     y = df2['Weekly_Sales_x'],
                     marker_color = 'Black',                    
                     name = 'Média de Vendas Semanais de Todas as Lojas'))

fig.add_trace(go.Bar(x = df2['Date'], 
                     y = df2['Weekly_Sales_y'],
                     marker_color = 'Red',
                     name = 'Vendas Semanais da loja 20'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
